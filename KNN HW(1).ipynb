# %% [markdown]
# Start: install packages (if necessary)

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Using cached scikit_learn-0.24.2-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/lib/python3/dist-packages (from scikit-learn) (1.13.3)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy>=0.19.1 in /usr/lib/python3/dist-packages (from scikit-learn) (0.19.1)
# Collecting joblib>=0.11
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.0.1 scikit-learn-0.24.2 threadpoolctl-2.2.0

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /usr/lib/python3/dist-packages (0.22.0)

# %% [markdown]
# End: install packages

# %% [markdown]
# Start: Data Preparation

# %%
import pandas as pd
file = 'iris.data'
col_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
df = pd.read_csv(file, header = None, names = col_names)
df
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 15            5.7          4.4           1.5          0.4     Iris-setosa
# 16            5.4          3.9           1.3          0.4     Iris-setosa
# 17            5.1          3.5           1.4          0.3     Iris-setosa
# 18            5.7          3.8           1.7          0.3     Iris-setosa
# 19            5.1          3.8           1.5          0.3     Iris-setosa
# 20            5.4          3.4           1.7          0.2     Iris-setosa
# 21            5.1          3.7           1.5          0.4     Iris-setosa
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 23            5.1          3.3           1.7          0.5     Iris-setosa
# 24            4.8          3.4           1.9          0.2     Iris-setosa
# 25            5.0          3.0           1.6          0.2     Iris-setosa
# 26            5.0          3.4           1.6          0.4     Iris-setosa
# 27            5.2          3.5           1.5          0.2     Iris-setosa
# 28            5.2          3.4           1.4          0.2     Iris-setosa
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 123           6.3          2.7           4.9          1.8  Iris-virginica
# 124           6.7          3.3           5.7          2.1  Iris-virginica
# 125           7.2          3.2           6.0          1.8  Iris-virginica
# 126           6.2          2.8           4.8          1.8  Iris-virginica
# 127           6.1          3.0           4.9          1.8  Iris-virginica
# 128           6.4          2.8           5.6          2.1  Iris-virginica
# 129           7.2          3.0           5.8          1.6  Iris-virginica
# 130           7.4          2.8           6.1          1.9  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 132           6.4          2.8           5.6          2.2  Iris-virginica
# 133           6.3          2.8           5.1          1.5  Iris-virginica
# 134           6.1          2.6           5.6          1.4  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 137           6.4          3.1           5.5          1.8  Iris-virginica
# 138           6.0          3.0           4.8          1.8  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_class = {'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2}
df['species_num'] = [iris_class[i] for i in df.species]

# %%
X = df.drop(['species', 'species_num'], axis=1)
y = df.species_num

# %%
from sklearn.model_selection import train_test_split
## Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .34)

# %% [markdown]
# End: Data Preparation

# %% [markdown]
# Start: Neighbors/Response/Accuracy

# %%
## Import the Classifier.
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics 
k = KNeighborsClassifier(n_neighbors=5)

k.fit(X_train, y_train)
y_pred = k.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.923076923077

# %%
def averageAcc(average_acc_per_k):
    averageIn = sum(average_acc_per_k)/5
    return averageIn

# %%
End: Neighbors/Response/Accuracy

# %%
Implementation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics 

def averageAcc(average_acc_per_k):
    averageIn = sum(average_acc_per_k)/5
    return averageIn

def main():

    file = 'iris.data'
    col_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
    df = pd.read_csv(file, header = None, names = col_names)
    iris_class = {'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2}
    df['species_num'] = [iris_class[i] for i in df.species]
    X = df.drop(['species', 'species_num'], axis=1)
    y = df.species_num
    accuracy = []
    average_acc_per_k = []
    #start loop to insert values and test n_neighbors here
    for i in range (1, 21):
        for j in range(1, 6):
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .34)
            k = KNeighborsClassifier(n_neighbors=i)
            k.fit(X_train, y_train)
            y_pred = k.predict(X_test)
            accuracy.append(metrics.accuracy_score(y_test, y_pred))
        
        average_acc_per_k.append(averageAcc(accuracy))
        accuracy.clear()
    
    print('Average Accuracy per K-value' + repr(average_acc_per_k))
    
main()
# Out:
# Average Accuracy per K-value[0.96538461538461529, 0.93461538461538463, 0.95769230769230762, 0.94999999999999996, 0.95769230769230762, 0.97307692307692295, 0.98076923076923084, 0.95384615384615379, 0.97307692307692295, 0.95769230769230762, 0.96538461538461529, 0.95769230769230762, 0.96923076923076912, 0.95384615384615401, 0.96923076923076912, 0.95769230769230762, 0.96153846153846145, 0.94230769230769229, 0.92307692307692313, 0.93076923076923079]

# %%
accuracy = [0]*5
print(repr(accuracy))
# Out:
# [0, 0, 0, 0, 0]
